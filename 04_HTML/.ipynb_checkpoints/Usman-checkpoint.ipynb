# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# Import basic libraries
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import gzip

# %%
test_df = pd.DataFrame(pd.read_csv('../00_Resources/fake-news/test.csv'))
test_df.head()
# Out:
#       id                                              title  \
# 0  20800  Specter of Trump Loosens Tongues, if Not Purse...
# 1  20801  Russian warships ready to strike terrorists ne...
# 2  20802  #NoDAPL: Native American Leaders Vow to Stay A...
# 3  20803  Tim Tebow Will Attempt Another Comeback, This ...
# 4  20804                    Keiser Report: Meme Wars (E995)
#
#                     author                                               text
# 0         David Streitfeld  PALO ALTO, Calif.  —   After years of scorning...
# 1                      NaN  Russian warships ready to strike terrorists ne...
# 2            Common Dreams  Videos #NoDAPL: Native American Leaders Vow to...
# 3            Daniel Victor  If at first you don’t succeed, try a different...
# 4  Truth Broadcast Network  42 mins ago 1 Views 0 Comments 0 Likes 'For th...

# %%
train_df = pd.DataFrame(pd.read_csv('../00_Resources/fake-news/train.csv'))
train_df.head()
# Out:
#    id                                              title              author  \
# 0   0  House Dem Aide: We Didn’t Even See Comey’s Let...       Darrell Lucus
# 1   1  FLYNN: Hillary Clinton, Big Woman on Campus - ...     Daniel J. Flynn
# 2   2                  Why the Truth Might Get You Fired  Consortiumnews.com
# 3   3  15 Civilians Killed In Single US Airstrike Hav...     Jessica Purkiss
# 4   4  Iranian woman jailed for fictional unpublished...      Howard Portnoy
#
#                                                 text  label
# 0  House Dem Aide: We Didn’t Even See Comey’s Let...      1
# 1  Ever get the feeling your life circles the rou...      0
# 2  Why the Truth Might Get You Fired October 29, ...      1
# 3  Videos 15 Civilians Killed In Single US Airstr...      1
# 4  Print \nAn Iranian woman has been sentenced to...      1

# %%
# Merge the two DataFrames together based on the Dates they share
model_df = pd.merge(test_df, train_df, on="text")
model_df.head()
# Out:
#     id_x                                            title_x       author_x  \
# 0  20824  Ann Coulter On C-Span Quotes VDARE.com’s Brime...  James Fulford
# 1  20824  Ann Coulter On C-Span Quotes VDARE.com’s Brime...  James Fulford
# 2  20824  Ann Coulter On C-Span Quotes VDARE.com’s Brime...  James Fulford
# 3  20824  Ann Coulter On C-Span Quotes VDARE.com’s Brime...  James Fulford
# 4  20824  Ann Coulter On C-Span Quotes VDARE.com’s Brime...  James Fulford
#
#   text  id_y                                            title_y  \
# 0         82                         Huma’s Weiner Dogs Hillary
# 1        169  Mohamad Khweis: Another “Virginia Man” (Palest...
# 2        295  A Connecticut Reader Reports Record Voter Regi...
# 3        470  BULLETIN: There ARE Righteous Jews For Trump!;...
# 4        592  Is your promising internet career over now Vin...
#
#                      author_y  label
# 0                Steve Sailer      1
# 1               James Fulford      1
# ...

# %%
selected_features = model_df

# %%
# Assign x and y values
X = model_df.drop("title_x", axis=1)
y = model_df["label"]

print(X.shape, y.shape)
# Out:
# (3271, 7) (3271,)

# %%
# Import Dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from tensorflow.keras.utils import to_categorical

# Split data into training and testing
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=115, stratify=y)

# %%
X_train.head()
# Out:
#        id_x             author_x  \
# 3082  25892                  NaN
# 3154  22790                  NaN
# 2294  25815  Patrick J. Buchanan
# 1131  23385        James Fulford
# 1470  23798      John Derbyshire
#
#                                                    text   id_y  \
# 3082                                                NaN  14933
# 3154  Nation Puts 2016 Election Into Perspective By ...  12870
# 2294                                                     12145
# 1131                                                       936
# 1470                                                     12374
#
#                                                 title_y         author_y  \
# 3082  La sortie du dernier livre inédit du Gorafi éc...              NaN
# 3154  Humanity’s Greatest Mysteries - The Onion - Am...              NaN
# 2294  Sailer In TAKIMAG On The UVA Rape Hoax: “Sabri...     Steve Sailer
# 1131  Hillary is Sick & Tired of Suffering from Wein...  Captain Craptek
# ...

# %%
# Scale the data
X_scaler = MinMaxScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
from tensorflow.keras.utils import to_categorical

# %%
# Step 1: Label encoder
label_encoder = LabelEncoder()
label_encoder.fit(y_train)
encoded_y_train = label_encoder.transform(y_train)
encoded_y_test = label_encoder.transform(y_test)

# %%
# Step 2: Convert encoded labels to one-hot-encoding
y_train_categorical = to_categorical(encoded_y_train)
y_test_categorical = to_categorical(encoded_y_test)

# %%
print(label_encoder.classes_)
# Out:
# [1]

# %%
encoded_y = label_encoder.transform(y)
pd.plotting.scatter_matrix(X, c=encoded_y, figsize=(40, 40));

# %%
model_df['title_x'].value_counts(normalize=True)
# Out:
# Obama Jump Filed Me Regarding Illegal Pardons                                                                                 0.023213
# Hillary’s High Crimes & Misdemeanors Threaten Constitutional Crisis                                                           0.023213
# The Importance of Comments Sections in Bringing ROLLING STONE to Justice                                                      0.023213
# Anonymous – World War 3 is imminent 2016                                                                                      0.023213
# WORLD WAR 3 – HILLARY V.S. TRUMP                                                                                              0.023213
#                                                                                                                                 ...
# 'If Trump loses, I'm grabbing my musket,' former congressman tweets                                                           0.000310
# ...

# %%
# ML libraries
from sklearn.pipeline import make_pipeline
from sklearn.linear_model import LinearRegression, ElasticNet, Ridge, Lasso
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder

# %%
# TODO: find out how to CountVectorize a multi-dimensional array.

X = model_df['title_x']
y = model_df['label']

# %%
# Split the data into training and testing
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

print(X.shape, y.shape)
# Out:
# (3271,) (3271,)
